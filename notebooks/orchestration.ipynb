# %% [markdown]
# ### Configs

# %%
DATASET = "/kaggle/input/datasets/khlaifiabilel/pastis/PASTIS"
FOLD    = 1
EPOCHS  = 65

# %% [markdown]
# ### Clone the repo and install dependecies

# %%
import os

REPO = "https://github.com/ayzrixsiev/multitemporal-crop-segmentation-inference"

if not os.path.isdir("/kaggle/working/utae"):
    # !git clone -q $REPO /kaggle/working/utae

# %cd /kaggle/working/utae
# !pip install -q geopandas

# %% [markdown]
# ### Run the training process

# %%
# !cd /kaggle/working/utae && python train_semantic.py --dataset_folder $DATASET --fold $FOLD --epochs $EPOCHS --batch_size 2

# %% [markdown]
# ### Create html page to showcase results

# %%
# !cd /kaggle/working/utae && python scripts/make_report.py --dataset_folder $DATASET --fold $FOLD

# %%
# !cp -r /kaggle/working/utae/results /kaggle/working/results
# !cp /kaggle/working/utae/report/index.html /kaggle/working/report.html
# !du -sh /kaggle/working/results /kaggle/working/report.html
